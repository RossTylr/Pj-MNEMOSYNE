# %% [markdown]
# # Experiment 3 — Attention Weights Visualisation
#
# **Status:** Not started

# %% [markdown]
# ## Hypothesis
#
# > Visualise attention weights to interpret temporal feature importance

# %% [markdown]
# # Experiment 2 — Patient-Only Baseline
#
# **Status:** Not started

# %% [markdown]
# ## Hypothesis
#
# > Establish patient-only survival prediction baseline for ablation comparison

# %% [markdown]
# # Experiment 1 — Distribution Shift
#
# **Status:** Not started

# %% [markdown]
# ## Hypothesis
#
# > **H4:** Peacekeeping-trained model degrades on drone-warfare data (ΔF1 > 0.15)
